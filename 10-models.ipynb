# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
model = smf.ols("tip ~ total_bill", data=tips)

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):           6.69e-34
# Time:                        10:12:18   Log-Likelihood:                -350.54
# No. Observations:                 244   AIC:                             705.1
# Df Residuals:                     242   BIC:                             712.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9203      0.160      5.761      0.000       0.606       1.235
# total_bill     0.1050      0.007     14.260      0.000       0.091       0.120
# ==============================================================================
# Omnibus:                       20.185   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.750
# Skew:                           0.443   Prob(JB):                     6.35e-09
# Kurtosis:                       4.711   Cond. No.                         53.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols("tip ~ total_bill + sex + smoker + day + size", data=tips)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     29.90
# Date:                Wed, 13 Dec 2023   Prob (F-statistic):           2.12e-29
# Time:                        10:14:31   Log-Likelihood:                -347.49
# No. Observations:                 244   AIC:                             711.0
# Df Residuals:                     236   BIC:                             739.0
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.5917      0.255      2.318      0.021       0.089       1.095
# sex[T.Female]     0.0324      0.141      0.230      0.819      -0.246       0.311
# smoker[T.No]      0.0849      0.146      0.581      0.561      -0.203       0.372
# day[T.Fri]        0.1198      0.279      0.430      0.668      -0.429       0.669
# day[T.Sat]       -0.0261      0.175     -0.149      0.882      -0.371       0.319
# day[T.Sun]        0.0701      0.181      0.386      0.700      -0.287       0.428
# total_bill        0.0943      0.010      9.922      0.000       0.076       0.113
# size              0.1770      0.089      1.987      0.048       0.001       0.353
# ==============================================================================
# Omnibus:                       27.933   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.677
# Skew:                           0.608   Prob(JB):                     3.64e-12
# Kurtosis:                       4.924   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(X=tips[["total_bill", "size"]], y=tips["tip"])
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.09271334, 0.19259779])

# %%
lr.intercept_
# Out:
# 0.6689447408125027

# %%
lr = linear_model.LinearRegression()
lr.fit(X=tips[["total_bill", "size", "smoker"]], y=tips["tip"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 lr = linear_model.LinearRegression()
# ----> 2 lr.fit(X=tips[["total_bill", "size", "smoker"]], y=tips["tip"])
#
# File ~\miniforge3\lib\site-packages\sklearn\linear_model\_base.py:692, in LinearRegression.fit(self, X, y, sample_weight)
#     684 X, y = self._validate_data(
#     685     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686 )
#     688 sample_weight = _check_sample_weight(
#     689     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     690 )
# --> 692 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     693     X,
#     694     y,
#     695     fit_intercept=self.fit_intercept,
#     696     normalize=_normalize,
#     697     copy=self.copy_X,
#     698     sample_weight=sample_weight,
#     699 )
#     701 # Sample weight can be implemented via a simple rescaling.
#     702 X, y, sample_weight_sqrt = _rescale_data(X, y, sample_weight)
#
# File ~\miniforge3\lib\site-packages\sklearn\linear_model\_base.py:262, in _preprocess_data(X, y, fit_intercept, normalize, copy, sample_weight, check_input)
#     259     sample_weight = np.asarray(sample_weight)
#     261 if check_input:
# --> 262     X = check_array(X, copy=copy, accept_sparse=["csr", "csc"], dtype=FLOAT_DTYPES)
#     263 elif copy:
#     264     if sp.issparse(X):
#
# File ~\miniforge3\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# ValueError: could not convert string to float: 'No'

# %%
# dummy variable encoding
# one-hot enconding

# %%
tips_subset = tips[["total_bill", "tip", "size", "smoker"]]
tips_subset.head()
# Out:
#    total_bill   tip  size smoker
# 0       16.99  1.01     2     No
# 1       10.34  1.66     3     No
# 2       21.01  3.50     3     No
# 3       23.68  3.31     2     No
# 4       24.59  3.61     4     No

# %%
pd.get_dummies(tips_subset)
# Out:
#      total_bill   tip  size  smoker_Yes  smoker_No
# 0         16.99  1.01     2           0          1
# 1         10.34  1.66     3           0          1
# 2         21.01  3.50     3           0          1
# 3         23.68  3.31     2           0          1
# 4         24.59  3.61     4           0          1
# ..          ...   ...   ...         ...        ...
# 239       29.03  5.92     3           0          1
# 240       27.18  2.00     2           1          0
# 241       22.67  2.00     2           1          0
# 242       17.82  1.75     2           0          1
# 243       18.78  3.00     2           0          1
#
# [244 rows x 5 columns]

# %%
tips_dummy = pd.get_dummies(tips_subset, drop_first=True)
tips_dummy
# Out:
#      total_bill   tip  size  smoker_No
# 0         16.99  1.01     2          1
# 1         10.34  1.66     3          1
# 2         21.01  3.50     3          1
# 3         23.68  3.31     2          1
# 4         24.59  3.61     4          1
# ..          ...   ...   ...        ...
# 239       29.03  5.92     3          1
# 240       27.18  2.00     2          0
# 241       22.67  2.00     2          0
# 242       17.82  1.75     2          1
# 243       18.78  3.00     2          1
#
# [244 rows x 4 columns]

# %%
y = tips_dummy.pop("tip")
y
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips_dummy
# Out:
#      total_bill  size  smoker_No
# 0         16.99     2          1
# 1         10.34     3          1
# 2         21.01     3          1
# 3         23.68     2          1
# 4         24.59     4          1
# ..          ...   ...        ...
# 239       29.03     3          1
# 240       27.18     2          0
# 241       22.67     2          0
# 242       17.82     2          1
# 243       18.78     2          1
#
# [244 rows x 3 columns]

# %%
lr = linear_model.LinearRegression()
lr.fit(X=tips_dummy, y=y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.09388839, 0.18033156, 0.08343255])

# %%
lr.intercept_
# Out:
# 0.6255829641796256

# %%
tips_dummy.columns
# Out:
# Index(['total_bill', 'size', 'smoker_No'], dtype='object')
